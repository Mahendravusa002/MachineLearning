# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import *

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('diabetes.csv') 
print(df.shape)
#print(df.columns)
df.describe().transpose().head()
# Out:
# (768, 9)
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')
#                count        mean         std  min   25%    50%     75%    max
# Pregnancies    768.0    3.845052    3.369578  0.0   1.0    3.0    6.00   17.0
# Glucose        768.0  120.894531   31.972618  0.0  99.0  117.0  140.25  199.0
# BloodPressure  768.0   69.105469   19.355807  0.0  62.0   72.0   80.00  122.0
# SkinThickness  768.0   20.536458   15.952218  0.0   0.0   23.0   32.00   99.0
# Insulin        768.0   79.799479  115.244002  0.0   0.0   30.5  127.25  846.0

# %%
target_column = ['DiabetesPedigreeFunction'] 
#print(target_column)
predictors = list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe().transpose().head()
# Out:
# ['DiabetesPedigreeFunction']
#                count      mean       std  min       25%       50%       75%  \
# Pregnancies    768.0  0.226180  0.198210  0.0  0.058824  0.176471  0.352941
# Glucose        768.0  0.607510  0.160666  0.0  0.497487  0.587940  0.704774
# BloodPressure  768.0  0.566438  0.158654  0.0  0.508197  0.590164  0.655738
# SkinThickness  768.0  0.207439  0.161134  0.0  0.000000  0.232323  0.323232
# Insulin        768.0  0.094326  0.136222  0.0  0.000000  0.036052  0.150414
#
#                max
# Pregnancies    1.0
# Glucose        1.0
# BloodPressure  1.0
# SkinThickness  1.0
# Insulin        1.0

# %%
X = df[predictors].values
y = df[target_column].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=40)
print(X_train.shape); print(X_test.shape)
# Out:
# (537, 8)
# (231, 8)

# %%
from sklearn.neural_network import MLPClassifier
'''from sklearn.preprocessing import StandardScaler, LabelEncoder
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)'''
y_train = np.array(y_train)
mlp = MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=500)
mlp.fit(X_train,y_train)

predict_train = mlp.predict(X_train)
predict_test = mlp.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8768\2397237633.py in <module>
#       6 y_train = np.array(y_train)
#       7 mlp = MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=500)
# ----> 8 mlp.fit(X_train,y_train)
#       9
#      10 predict_train = mlp.predict(X_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#     750             Returns a trained MLP model.
#     751         """
# --> 752         return self._fit(X, y, incremental=False)
#     753
#     754     def _check_solver(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     391         )
#     392
# --> 393         X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     394
#     395         n_samples, n_features = X.shape
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _validate_input(self, X, y, incremental, reset)
#    1129         if (not hasattr(self, "classes_")) or (not self.warm_start and not incremental):
#    1130             self._label_binarizer = LabelBinarizer()
# -> 1131             self._label_binarizer.fit(y)
#    1132             self.classes_ = self._label_binarizer.classes_
#    1133         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit(self, y)
#     299
#     300         self.sparse_input_ = sp.issparse(y)
# --> 301         self.classes_ = unique_labels(y)
#     302         return self
#     303
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      99     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#        0.14297521, 0.13801653, 0.30743802, 0.03471074, 0.37355372,
#        0.70165289, 0.11735537, 0.1392562 , 0.57479339, 0.29049587,
#        0.11157025, 0.0677686 , 0.34917355, 0.10495868, 0.17933884,
#        0.27520661, 0.0785124 , 0.07066116, 0.08471074, 0.1661157 ,
#        0.0768595 , 0.25206612, 0.14917355, 0.12190083, 0.30495868,
#        0.10495868, 0.13719008, 0.26735537, 0.33099174, 0.09876033,
#        0.15330579, 0.10413223, 0.09834711, 0.14421488, 0.12561983,
#        0.21487603, 0.36280992, 0.10909091, 0.09834711, 0.11859504,
#        0.39504132, 0.14256198, 0.06652893, 0.23099174, 0.17644628,
#        0.05950413, 0.2838843 , 0.08181818, 0.10123967, 0.09793388,
#        0.08553719, 0.16157025, 0.07727273, 0.06322314, 0.22396694,
#        0.25      , 0.3822314 , 0.12603306, 0.21487603, 0.12231405,
#        0.12975207, 0.05867769, 0.15082645, 0.06115702, 0.31446281,
#        0.19958678, 0.22272727, 0.09214876, 0.15702479, 0.09752066,
#        0.12272727, 0.31652893, 0.28595041, 0.36900826, 0.08016529,
#        0.10743802, 0.10082645, 0.50123967, 0.20165289, 0.42727273,
#        0.10785124, 0.24090909, 0.22892562, 0.21694215, 0.09132231,
#        0.11570248, 0.15082645, 0.23512397, 0.14090909, 0.09793388,
#        0.39752066, 0.0838843 , 0.12066116, 0.09049587, 0.15495868,
#        0.08966942, 0.60371901, 0.27024793, 0.19256198, 0.19917355,
#        0.13429752, 0.14049587, 0.16652893, 0.05785124, 0.13884298,
#        0.26694215, 0.06570248, 0.08181818, 0.10867769, 0.11983471,
#        0.0446281 , 0.34669421, 0.12561983, 0.34090909, 0.22396694,
#        0.14793388, 0.11983471, 0.4446281 , 0.16900826, 0.18429752,
#        0.03512397, 0.18140496, 0.10702479, 0.46033058, 0.18636364,
#        0.05      , 0.24710744, 0.06487603, 0.12933884, 0.46942149,
#        0.06239669, 0.2607438 , 0.10082645, 0.06528926, 0.05041322,
#        0.18140496, 0.21280992, 0.09545455, 0.18305785, 0.3946281 ,
#        0.10247934, 0.22768595, 0.28347107, 0.08512397, 0.0322314 ,
#        0.0731405 , 0.13471074, 0.17975207, 0.29834711, 0.0553719 ,
#        0.10785124, 0.28595041]),)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_train,predict_train))
print(classification_report(y_train,predict_train))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8768\2188203955.py in <module>
#       1 from sklearn.metrics import classification_report,confusion_matrix
# ----> 2 print(confusion_matrix(y_train,predict_train))
#       3 print(classification_report(y_train,predict_train))
#
# NameError: name 'predict_train' is not defined

# %%
print(confusion_matrix(y_test,predict_test))
print(classification_report(y_test,predict_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8768\3456670055.py in <module>
# ----> 1 print(confusion_matrix(y_test,predict_test))
#       2 print(classification_report(y_test,predict_test))
#
# NameError: name 'predict_test' is not defined
