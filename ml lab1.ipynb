# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('Z:\Salary_Data.csv')
print(df.head())
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)
print(x_train)
print(x_test)
print(y_test)
print(y_train)
# Out:
# [[ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]
# [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]]
# [ 37731. 122391.  57081.  63218. 116969. 109431. 112635.  55794.  83088.
#  101302.]
# [ 56642.  66029.  64445.  61111. 113812.  91738.  46205. 121872.  60150.
#   39891.  81363.  93940.  57189.  54445. 105582.  43525.  39343.  98273.
#   67938.  56957.]

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
x_pred=regressor.predict(x_train)

# %%
plt.scatter(x_train,y_train,color="green")
plt.plot(x_train,x_pred,color='red')
plt.title("Experience vs salary(Train dataset)")
plt.xlabel("Experience")
plt.ylabel("salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color="green")
plt.plot(x_train,x_pred,color='red')
plt.title("Experience vs salary(Test dataset)")
plt.xlabel("Experience")
plt.ylabel("salary")
plt.show()

# %%
df=pd.read_csv('Z:\Machine learning\Salary_Data.csv')
print(df.head())
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
plt.scatter(data=df,x='Age',y='Salary')
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()

# %%
plt.scatter(data=df,x='YearsExperience',y='Salary')
plt.xlabel("YearsExperiance")
plt.ylabel("Salary")
plt.title("YearsExperience vs Salary")
plt.show()

# %%
x=df.iloc[:28,1:2].values  #age
y=df.iloc[:28,2].values  #salary
print(y)
print(x)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635]
# [[21. ]
#  [21.5]
#  [21.7]
#  [22. ]
#  [22.2]
#  [23. ]
#  [23. ]
#  [23.3]
#  [23.3]
#  [23.6]
#  [23.9]
#  [24. ]
#  [24. ]
#  [24. ]
#  [25. ]
#  [25. ]
#  [26. ]
#  [27. ]
#  [28. ]
#  [29. ]
#  [30. ]
#  [30. ]
#  [31. ]
#  [32. ]
#  [33. ]
#  [34. ]
#  [35. ]
#  [36. ]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
x_pred=regressor.predict(x_train)

# %%
plt.scatter(x_train,y_train,color="green")
plt.plot(x_train,x_pred,color='red')
plt.title("Age vs salary(Train dataset)")
plt.xlabel("Age")
plt.ylabel("salary")
plt.show()

# %%
plt.scatter(x_test,y_test,color="green")
plt.plot(x_train,x_pred,color='red')
plt.title("Age vs salary(Test dataset)")
plt.xlabel("Age")
plt.ylabel("salary")
plt.show()

# %%
x=df.iloc[:28,0:1].values  #age
y=df.iloc[:28,2].values  #salary
print(y)
print(x)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635]
# [[1.1]
#  [1.3]
#  [1.5]
#  [2. ]
#  [2.2]
#  [2.9]
#  [3. ]
#  [3.2]
#  [3.2]
#  [3.7]
#  [3.9]
#  [4. ]
#  [4. ]
#  [4.1]
#  [4.5]
#  [4.9]
#  [5.1]
#  [5.3]
#  [5.9]
#  [6. ]
#  [6.8]
#  [7.1]
#  [7.9]
#  [8.2]
#  [8.7]
#  [9. ]
#  [9.5]
#  [9.6]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1=train_test_split(x,y,test_size=1/3,random_state=0)
print(x_train1)
print(x_test1)
print(y_test1)
print(y_train1)
# Out:
# [[5.1]
#  [1.3]
#  [3.9]
#  [9.6]
#  [9.5]
#  [3.2]
#  [3. ]
#  [2.2]
#  [5.9]
#  [6. ]
#  [3.7]
#  [3.2]
#  [8.2]
#  [2. ]
#  [1.1]
#  [7.1]
#  [4.9]
#  [4. ]]
# [[1.5]
#  [7.9]
#  [4.5]
#  [5.3]
#  [2.9]
#  [4. ]
#  [8.7]
#  [4.1]
#  [6.8]
#  [9. ]]
# [ 37731 101302  61111  83088  56642  55794 109431  57081  91738 105582]
# [ 66029  46205  63218 112635 116969  64445  60150  39891  81363  93940
#   57189  54445 113812  43525  39343  98273  67938  56957]

# %%
regressor=LinearRegression()
regressor.fit(x_train1,y_train1)
# Out:
# LinearRegression()

# %%
y_pred1=regressor.predict(x_test1)
x_pred1=regressor.predict(x_train1)

# %%
plt.scatter(x_train1,y_train1,color="green")
plt.plot(x_train1,x_pred1,color='red')
plt.title("Age vs salary(Train dataset)")
plt.xlabel("Age")
plt.ylabel("salary")
plt.show()

# %%
#plt.scatter(x_test,y_test,color="blue")
plt.scatter(x_test1,y_test1,color="green")
plt.plot(x_train1,x_pred1,color='red')
#plt.plot(x_train,x_pred,color='black')
plt.title("Age vs salary(Test dataset)")
plt.xlabel("Age")
plt.ylabel("salary")
plt.show()
